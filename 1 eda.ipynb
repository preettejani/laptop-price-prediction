# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_croma_laptops.csv")
print(df.shape)
print(df.info())
print(df.head())
# Out:
# (473, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 473 entries, 0 to 472
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Brand        473 non-null    object
#  1   Screen Size  473 non-null    float64
#  2   Color        473 non-null    object
#  3   RAM          473 non-null    int64
#  4   Storage      473 non-null    float64
#  5   GPU          473 non-null    object
#  6   CPU          473 non-null    object
#  7   Price        473 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 29.7+ KB
# None
#    Brand  Screen Size   Color  RAM  Storage         GPU                 CPU  \
# 0  Apple         13.3    Gray    8    256.0  Integrated  Intel Core i5 13th
# 1  Apple         13.3    Gold    8    256.0  Integrated  Intel Core i5 13th
# 2  Apple         13.3  Silver    8    256.0  Integrated  Intel Core i5 13th
# 3  Apple         14.2   Black   24    512.0  Integrated  Intel Core i5 13th
# 4  Apple         13.6  Silver   16    256.0  Integrated  Intel Core i5 13th
#
#       Price
# 0   54490.0
# 1   54490.0
# 2   54490.0
# 3  187990.0
# 4   93990.0

# %%
print(df.isnull().sum())
# Out:
# Brand          0
# Screen Size    0
# Color          0
# RAM            0
# Storage        0
# GPU            0
# CPU            0
# Price          0
# dtype: int64

# %%
print(df.describe())
# Out:
#        Screen Size         RAM      Storage          Price
# count   473.000000  473.000000   473.000000     473.000000
# mean     15.008879   16.541226   624.904863  103229.435518
# std       1.062758    7.579724   271.019469   66894.898656
# min      13.300000    4.000000     4.000000   16984.000000
# 25%      14.000000   16.000000   512.000000   59990.000000
# 50%      15.600000   16.000000   512.000000   85990.000000
# 75%      15.600000   16.000000  1000.000000  125990.000000
# max      27.000000   48.000000  2000.000000  424990.000000

# %%
import matplotlib.pyplot as plt

numeric_cols = df.select_dtypes(include=['int64','float64']).columns
for col in numeric_cols:
    df[col].hist(bins=30, figsize=(6,4))
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()
