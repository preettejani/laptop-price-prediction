# %%
# # import pandas as pd
# # import re

# # # Load dataset
# # file_path = "croma_laptops.csv"  # change path if needed
# # df = pd.read_csv(file_path)

# # # Extraction function
# # def extract_specs(name):
# #     # Brand = first word
# #     brand = name.split()[0] if name else None

# #     # Screen Size
# #     screen_size = re.search(r'(\d{2}\.?\d?\s*inch)', name, re.IGNORECASE)
# #     screen_size = screen_size.group(1) if screen_size else None

# #     # Color
# #     color = re.search(r'(Silver|Gray|Grey|Black|Blue|Gold|White|Green)', name, re.IGNORECASE)
# #     color = color.group(1) if color else None

# #     # RAM
# #     ram = re.search(r'(\d+GB)\s*RAM', name, re.IGNORECASE)
# #     if not ram:
# #         ram = re.search(r'(\d+GB)', name, re.IGNORECASE)
# #     ram = ram.group(1) if ram else None

# #     # Storage
# #     storage = re.search(r'(\d+TB|\d+GB)', name, re.IGNORECASE)
# #     storage = storage.group(1) if storage else None

# #     # GPU
# #     gpu = re.search(r'(NVIDIA\s+[^\s,]+|Radeon\s+[^\s,]+|Apple\s+GPU|Intel\s+Iris\s+Xe)', name, re.IGNORECASE)
# #     gpu = gpu.group(1) if gpu else None

# #     # CPU
# #     cpu = re.search(r'(Intel\s+[^\s,]+|AMD\s+[^\s,]+|M\d\s*Pro?|M\d)', name, re.IGNORECASE)
# #     cpu = cpu.group(1) if cpu else None

# #     return pd.Series([brand, screen_size, color, ram, storage, gpu, cpu])

# # # Apply extraction
# # df[['Brand',  'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU']] = df['Name'].apply(extract_specs)

# # # Keep required columns with price
# # df_cleaned = df[['Brand', 'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU', 'Price']]

# # df_cleaned.head()











# import pandas as pd
# import re

# file_path = "croma_laptops.csv" 
# df = pd.read_csv(file_path)

# def extract_specs(name):
#     # Brand = first word
#     brand = name.split()[0] if name else None

#     # Screen Size
#     screen_size = re.search(r'(\d{2}\.?\d?\s*inch)', name, re.IGNORECASE)
#     screen_size = screen_size.group(1) if screen_size else None

#     # Color
#     color = re.search(r'(Silver|Gray|Grey|Black|Blue|Gold|White|Green)', name, re.IGNORECASE)
#     color = color.group(1) if color else None

#     # RAM
#     ram = re.search(r'(\d+GB)\s*RAM', name, re.IGNORECASE)
#     if not ram:
#         ram = re.search(r'(\d+GB)', name, re.IGNORECASE)
#     ram = ram.group(1) if ram else None

#     # Storage (must come AFTER RAM if RAM exists)
#     storage = None
#     if ram:
#         match = re.search(rf'{ram}.*?(\d+TB|\d+GB)', name, re.IGNORECASE)
#         if match:
#             storage = match.group(1)
#     if not storage:  # fallback if RAM not found or storage alone present
#         match = re.search(r'(\d+TB|\d+GB)', name, re.IGNORECASE)
#         if match:
#             storage = match.group(1)

#     # GPU
#     gpu = re.search(r'(NVIDIA\s+[^\s,]+|Radeon\s+[^\s,]+|Apple\s+GPU|Intel\s+Iris\s+Xe)', name, re.IGNORECASE)
#     gpu = gpu.group(1) if gpu else None

#     # CPU
#     cpu = re.search(r'(Intel\s+[^\s,]+|AMD\s+[^\s,]+|M\d\s*Pro?|M\d)', name, re.IGNORECASE)
#     cpu = cpu.group(1) if cpu else None

#     return pd.Series([brand, screen_size, color, ram, storage, gpu, cpu])

# # Apply extraction
# df[['Brand', 'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU']] = df['Name'].apply(extract_specs)

# # Keep required columns with price
# df_cleaned = df[['Brand', 'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU', 'Price']]

# # Preview cleaned data
# print(df_cleaned.head())








import pandas as pd
import re

# Load dataset
file_path = "croma_laptops.csv"
df = pd.read_csv(file_path)

def extract_specs(name):
    # Brand = first word
    brand = name.split()[0] if name else None

    # Screen Size
    screen_size = re.search(r'(\d{2}\.?\d?\s*inch)', name, re.IGNORECASE)
    screen_size = screen_size.group(1) if screen_size else None

    # Color
    color = re.search(r'(Silver|Gray|Grey|Black|Blue|Gold|White|Green)', name, re.IGNORECASE)
    color = color.group(1) if color else None

    # RAM
    ram = re.search(r'(\d+GB)\s*RAM', name, re.IGNORECASE)
    if not ram:
        ram = re.search(r'(\d+GB)', name, re.IGNORECASE)
    ram = ram.group(1) if ram else None

    # Storage (must come AFTER RAM if RAM exists)
    storage = None
    if ram:
        match = re.search(rf'{ram}.*?(\d+TB|\d+GB)', name, re.IGNORECASE)
        if match:
            storage = match.group(1)
    if not storage:  # fallback if RAM not found or storage alone present
        match = re.search(r'(\d+TB|\d+GB)', name, re.IGNORECASE)
        if match:
            storage = match.group(1)

    # GPU
    gpu = re.search(r'(NVIDIA\s+[^\s,]+|Radeon\s+[^\s,]+|Apple\s+GPU|Intel\s+Iris\s+Xe)', name, re.IGNORECASE)
    gpu = gpu.group(1) if gpu else None

    # CPU (improved regex for full model names)
    cpu = re.search(
        r'(Intel\s+Core\s+i\d{1,2}(?:\s*\w+)?(?:\s*\d{1,2}(?:th|st|nd|rd)\s*Gen)?)|'
        r'(AMD\s+Ryzen\s+\d+(?:\s*\w+)?(?:\s*\d{1,2}(?:th|st|nd|rd)\s*Gen)?)|'
        r'(Apple\s+M\d(?:\s*Pro|\s*Max|\s*Ultra)?)',
        name,
        re.IGNORECASE
    )
    cpu = cpu.group(0).strip() if cpu else None

    return pd.Series([brand, screen_size, color, ram, storage, gpu, cpu])

# Apply extraction
df[['Brand', 'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU']] = df['Name'].apply(extract_specs)

# Keep required columns with price
df_cleaned = df[['Brand', 'Screen Size', 'Color', 'RAM', 'Storage', 'GPU', 'CPU', 'Price']]

df_cleaned.head()
# Out:
#    Brand Screen Size   Color   RAM Storage   GPU   CPU     Price
# 0  Apple   13.3 inch    Gray   8GB   256GB  None  None   54490.0
# 1  Apple   13.3 inch    Gold   8GB   256GB  None  None   54490.0
# 2  Apple   13.3 inch  Silver   8GB   256GB  None  None   54490.0
# 3  Apple   14.2 inch   Black  24GB   512GB  None  None  187990.0
# 4  Apple   13.6 inch    None  16GB   256GB  None  None   93990.0

# %%
df_cleaned['Screen Size'] = df_cleaned['Screen Size'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\4090165296.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Screen Size'] = df_cleaned['Screen Size'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)

# %%
df_cleaned['RAM'] = df_cleaned['RAM'].astype(str).str.replace("GB", "", regex=False).str.strip().astype(int)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\446471098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['RAM'] = df_cleaned['RAM'].astype(str).str.replace("GB", "", regex=False).str.strip().astype(int)

# %%
df_cleaned['Storage'] = (
    df_cleaned['Storage'].astype(str)
    .str.replace("GB", "", regex=False)
    .str.replace("TB", "000", regex=False) 
    .str.extract(r'(\d+)')
    .astype(float)
)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\717371732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Storage'] = (

# %%
df_cleaned['GPU'].value_counts()
# Out:
# GPU
# NVIDIA GeForce     100
# Intel Iris Xe       14
# NVIDIA Geforce       3
# Radeon Graphics      2
# Radeon RX            1
# Radeon 610M          1
# NVIDIA GTX           1
# Name: count, dtype: int64

# %%
df_cleaned.isnull().sum()
# Out:
# Brand            0
# Screen Size      0
# Color           62
# RAM              0
# Storage          0
# GPU            351
# CPU            256
# Price            0
# dtype: int64

# %%
df.shape
# Out:
# (473, 10)

# %%
df_cleaned['Brand'] = df_cleaned['Brand'].astype(str)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\471025406.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Brand'] = df_cleaned['Brand'].astype(str)

# %%
df_cleaned.loc[(df_cleaned['Brand'].str.lower() == 'apple') & (df_cleaned['GPU'].isna()),'GPU'] = "Integrated"

# %%
df_cleaned.isnull().sum()
# Out:
# Brand            0
# Screen Size      0
# Color           62
# RAM              0
# Storage          0
# GPU            252
# CPU            256
# Price            0
# dtype: int64

# %%
df_cleaned['GPU'] = df_cleaned['GPU'].fillna("Integrated")
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\3687147286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['GPU'] = df_cleaned['GPU'].fillna("Integrated")

# %%
color_mode = df_cleaned['Color'].mode()[0]

# %%
df_cleaned['Color'] = df_cleaned['Color'].fillna(color_mode)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\2532763798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['Color'] = df_cleaned['Color'].fillna(color_mode)

# %%
df_cleaned.isnull().sum()
# Out:
# Brand            0
# Screen Size      0
# Color            0
# RAM              0
# Storage          0
# GPU              0
# CPU            256
# Price            0
# dtype: int64

# %%
cpu_mode = df_cleaned['CPU'].mode()[0]
df_cleaned['CPU'] = df_cleaned['CPU'].fillna(cpu_mode)
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_20996\2964110142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['CPU'] = df_cleaned['CPU'].fillna(cpu_mode)

# %%
df_cleaned.to_csv("cleaned_croma_laptops.csv", index=False)

# %%
df_cleaned.head()
# Out:
#    Brand  Screen Size   Color  RAM  Storage         GPU                 CPU  \
# 0  Apple         13.3    Gray    8    256.0  Integrated  Intel Core i5 13th
# 1  Apple         13.3    Gold    8    256.0  Integrated  Intel Core i5 13th
# 2  Apple         13.3  Silver    8    256.0  Integrated  Intel Core i5 13th
# 3  Apple         14.2   Black   24    512.0  Integrated  Intel Core i5 13th
# 4  Apple         13.6  Silver   16    256.0  Integrated  Intel Core i5 13th
#
#       Price
# 0   54490.0
# 1   54490.0
# 2   54490.0
# 3  187990.0
# 4   93990.0

# %%
df_cleaned
# Out:
#        Brand  Screen Size   Color  RAM  Storage         GPU  \
# 0      Apple         13.3    Gray    8    256.0  Integrated
# 1      Apple         13.3    Gold    8    256.0  Integrated
# 2      Apple         13.3  Silver    8    256.0  Integrated
# 3      Apple         14.2   Black   24    512.0  Integrated
# 4      Apple         13.6  Silver   16    256.0  Integrated
# ..       ...          ...     ...  ...      ...         ...
# 468     DELL         16.3  Silver   32   1000.0  Integrated
# 469  SAMSUNG         14.0    Gray   16   1000.0  Integrated
# 470  SAMSUNG         14.0    Gray   16    512.0  Integrated
# 471  SAMSUNG         14.0    Gray   32   1000.0  Integrated
# 472     DELL         15.6  Silver   16    512.0  Integrated
#
#                     CPU     Price
# 0    Intel Core i5 13th   54490.0
# 1    Intel Core i5 13th   54490.0
# 2    Intel Core i5 13th   54490.0
# 3    Intel Core i5 13th  187990.0
# 4    Intel Core i5 13th   93990.0
# ..                  ...       ...
# 468  Intel Core i5 13th  327199.0
# 469  Intel Core i5 13th  145990.0
# 470  Intel Core i5 13th  139990.0
# 471  Intel Core i5 13th  171990.0
# 472  Intel Core i5 13th   61990.0
#
# [473 rows x 8 columns]
